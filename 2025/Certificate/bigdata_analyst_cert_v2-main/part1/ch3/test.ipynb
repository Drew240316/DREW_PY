# %% [markdown]
# 0을 제외하고, view컬럼 결측치를 최소값으로 채우세요.
# 그리고 view 컬럼 중앙값을 구하세요.

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

# %%
cond = df['f5'] != 0
df = df[cond]

# %%
min = df['views'].min()
df['views'].fillna(min, inplace = True)
df['views'].median()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21416\2557412062.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['views'].fillna(min, inplace = True)
# np.float64(5924.0)

# %%
df
# Out:
#         id    age city    f1  f2    f3    f4         f5  subscribed    views
# 0     id01    2.0   서울   NaN   0  gold  ENFJ  91.297791  2024-07-16   6820.0
# 1     id02    9.0   서울  70.0   1   NaN  ENFJ  60.339826  2024-05-12   2534.0
# 2     id03   27.0   서울  61.0   1  gold  ISTJ  17.252986  2024-03-16   7312.0
# 3     id04   75.0   서울   NaN   2   NaN  INFP  52.667078  2024-07-21    493.0
# 4     id05   24.0   서울  85.0   2   NaN  ISFJ  29.269869  2024-03-07   1338.0
# ..     ...    ...  ...   ...  ..   ...   ...        ...         ...      ...
# 97    id97  100.0   경기   NaN   0  gold  INFP  67.886373  2024-03-18   6687.0
# 98    id98   39.0   경기  58.0   2   NaN  INFP  98.429899  2024-10-02    865.0
# 99    id99    1.0   경기  47.0   0  gold  ESFJ  97.381034  2024-12-02   6090.0
# 100  id100   47.0   경기  53.0   0   vip  ESFP  33.308999  2024-02-21  15535.0
# 101   id68   35.0   경기  45.0   2  gold  ISFP  67.886373  2024-07-29   8599.0
#
# [102 rows x 10 columns]

# %% [markdown]
# subscribed종류 중 가장 많은 날짜 구하고, 일 값을 찾고 정수형으로 변경

# %%
import pandas as pd

df = pd.read_csv('type1_data1.csv')

# %%
df
# Out:
#         id   age city    f1  f2      f3    f4         f5  subscribed   views
# 0     id01   2.0   서울   NaN   0    gold  ENFJ  91.297791  2024-07-16  6820.0
# 1     id02   9.0   서울  70.0   1     NaN  ENFJ  60.339826  2024-05-12  2534.0
# 2     id03  27.0   서울  61.0   1    gold  ISTJ  17.252986  2024-03-16  7312.0
# 3     id04  75.0   서울   NaN   2     NaN  INFP  52.667078  2024-07-21   493.0
# 4     id05  24.0   서울  85.0   2     NaN  ISFJ  29.269869  2024-03-07  1338.0
# ..     ...   ...  ...   ...  ..     ...   ...        ...         ...     ...
# 115  id114  22.0   대구  23.0   0    gold  INTP   0.000000  2025-02-17  9747.0
# 116  id115  23.0   부산  65.0   0     vip  ENTP   0.000000  2025-02-17  5628.0
# 117  id116  23.0   서울  12.0   1  silver  INFP   0.000000  2025-02-17  1267.0
# 118  id117  23.0   대구  65.0   2    gold  INFP   0.000000  2025-02-17  6543.0
# 119  id118  24.0   부산  94.0   1     vip  ESFJ   0.000000  2025-02-17  2356.0
#
# [120 rows x 10 columns]

# %%
df=df['subscribed'].value_counts()
print(df.index[0][-2:])
# Out:
# 17

# %%
import pandas as pd

df = pd.read_csv('type1_data1.csv')

# %% [markdown]
# 결측치를 제거하고, 새로운 new컬럼을 계산한다.(views를 fi으로 나눠라)
# 그리고 내림차순 정렬한다.
# 마지막으로 age의 첫번재 값을 찾는다.

# %%
df = df.dropna()

# %%
df['new'] = (df['views']/df['f1'])

# %%
df  = df.sort_values('new', ascending = False)

# %%
df
# Out:
#         id   age city     f1  f2      f3    f4         f5  subscribed  \
# 115  id114  22.0   대구   23.0   0    gold  INTP   0.000000  2025-02-17
# 83    id83  73.0   경기   50.0   1     vip  ENTP  80.138280  2024-09-26
# 5     id06  22.0   서울   57.0   0     vip  INTP  20.129444  2024-09-12
# 105  id104  21.0   서울   13.0   0  silver  ESFJ   0.000000  2025-02-17
# 106  id105  21.0   경기   24.0   0    gold  ESFJ   0.000000  2025-02-17
# ..     ...   ...  ...    ...  ..     ...   ...        ...         ...
# 109  id108  21.0   서울   54.0   1    gold  ESTJ   0.000000  2025-02-17
# 57    id57   3.0   대구  111.0   0  silver  ISFJ  29.269869  2024-01-12
# 7     id08  38.0   서울  101.0   1  silver  INFJ  83.685380  2024-03-06
# 108  id107  21.0   부산   76.0   1  silver  ESTJ   0.000000  2025-02-17
# 119  id118  24.0   부산   94.0   1     vip  ESFJ   0.000000  2025-02-17
#
#        views         new
# 115   9747.0  423.782609
# 83   19139.0  382.780000
# 5    21550.0  378.070175
# ...

# %%
print(df.iloc[0,1])
# Out:
# 22.0

# %% [markdown]
# ##### views를 결측 데이터 0으로 대체
# ##### 내림차순 정렬
# ##### views 상위 10개 데이터에 최소값 대입
# ##### views 컬럼의 합을 구해라

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')
df = df.sort_values('views', ascending = False)
min_result = df.iloc[:10].min()

# %%
df.iloc[10:-1] = min_result

# %%
int(df['views'].sum())
# Out:
# 1229120

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

# %%
df['views'].fillna(0, inplace=True)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21416\1393355345.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['views'].fillna(0, inplace=True)

# %%
value = df['views'].nlargest(10).iloc[-1]

# %%
df.loc[df['views'] >value , 'views'] = value

# %%
df.loc[df['views'] > value , 'views'] = value

# %%
int(df['views'].sum())
# Out:
# 652812

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')
df
# Out:
#         id   age city    f1  f2      f3    f4         f5  subscribed   views
# 0     id01   2.0   서울   NaN   0    gold  ENFJ  91.297791  2024-07-16  6820.0
# 1     id02   9.0   서울  70.0   1     NaN  ENFJ  60.339826  2024-05-12  2534.0
# 2     id03  27.0   서울  61.0   1    gold  ISTJ  17.252986  2024-03-16  7312.0
# 3     id04  75.0   서울   NaN   2     NaN  INFP  52.667078  2024-07-21   493.0
# 4     id05  24.0   서울  85.0   2     NaN  ISFJ  29.269869  2024-03-07  1338.0
# ..     ...   ...  ...   ...  ..     ...   ...        ...         ...     ...
# 115  id114  22.0   대구  23.0   0    gold  INTP   0.000000  2025-02-17  9747.0
# 116  id115  23.0   부산  65.0   0     vip  ENTP   0.000000  2025-02-17  5628.0
# 117  id116  23.0   서울  12.0   1  silver  INFP   0.000000  2025-02-17  1267.0
# 118  id117  23.0   대구  65.0   2    gold  INFP   0.000000  2025-02-17  6543.0
# 119  id118  24.0   부산  94.0   1     vip  ESFJ   0.000000  2025-02-17  2356.0
#
# [120 rows x 10 columns]

# %%
df['new'] = df['f4'].str[2:4]

# %%
cond = df['new'] == 'FJ'

# %%
df = df[cond]

# %%
print(round(df['f2'].mean(),2))
# Out:
# 0.61

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")
cond = df['f4'].str.contains('FJ')
df = df[cond]

# %%
df
# Out:
#         id   age city     f1  f2      f3    f4         f5  subscribed    views
# 0     id01   2.0   서울    NaN   0    gold  ENFJ  91.297791  2024-07-16   6820.0
# 1     id02   9.0   서울   70.0   1     NaN  ENFJ  60.339826  2024-05-12   2534.0
# 4     id05  24.0   서울   85.0   2     NaN  ISFJ  29.269869  2024-03-07   1338.0
# 6     id07  36.3   서울   60.0   1     NaN  ISFJ   9.796378  2024-01-11     61.0
# 7     id08  38.0   서울  101.0   1  silver  INFJ  83.685380  2024-03-06   3260.0
# 8     id09   3.3   서울   35.0   2     NaN  ESFJ  17.252986  2024-03-21   2764.0
# 13    id13  15.0   서울   68.0   0    gold  ESFJ  83.685380  2024-12-30   5643.0
# 18    id18  41.0   서울   87.0   2    gold  ISFJ  80.138280  2024-03-03   7933.0
# 24    id24  80.0   부산   44.0   0    gold  INFJ  73.586397  2024-09-11   5976.0
# 31    id31  86.0   부산   77.0   0    gold  ESFJ  73.586397  2024-02-11   8014.0
# 32    id32  25.0   부산   64.0   0     vip  ISFJ  13.049921  2024-05-24  17421.0
# ...

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

cond1 = df['f3'] == 'gold'
cond2 = df['f2'] == 2
df = df[cond1&cond2]

# %%
df
# Out:
#         id   age city    f1  f2    f3    f4         f5  subscribed   views
# 18    id18  41.0   서울  87.0   2  gold  ISFJ  80.138280  2024-03-03  7933.0
# 29    id29 -13.5   부산  47.0   2  gold  ENTP  67.886373  2024-08-28  6793.0
# 42    id42  65.0   대구  48.0   2  gold  ESTP  33.308999  2024-02-09  5999.0
# 55    id55  75.0   대구  63.0   2  gold  ENTP  13.049921  2024-02-06  6042.0
# 64    id64  43.0   경기  62.0   2  gold  ESFP  73.586397  2024-02-22  5995.0
# 68    id68  35.0   경기  45.0   2  gold  ISFP  67.886373  2024-07-29  8599.0
# 71    id71  35.0   경기  84.0   2  gold  ISFP  52.667078  2024-07-15  8087.0
# 101   id68  35.0   경기  45.0   2  gold  ISFP  67.886373  2024-07-29  8599.0
# 112  id111  22.0   부산  65.0   2  gold  ENTP   0.000000  2025-02-17  7894.0
# 118  id117  23.0   대구  65.0   2  gold  INFP   0.000000  2025-02-17  6543.0

# %%
result = df['f1'].var()

# %%
print(round(result,2))
# Out:
# 235.43

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

# %%
df['age'] = df['age'] + 1

# %%
cond1 = (df['age'] >= 20) & ( df['age'] < 30 )
cond2 = ( df['age'] >=30 ) & ( df['age'] < 40 )
result = abs( df[cond1]['views'].mean() - df[cond2]['views'].mean() )
print( round(result,2)  )
# Out:
# 263.13

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

df['subscribed'] = pd.to_datetime(df['subscribed'])

# %%
import pandas as pd
df['subscribed'] = pd.read_csv('type1_data1.csv')
df = pd.to_datetime(df['subscribed'])

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[228], line 3
#       1 import pandas as pd
#       2 df['subscribed'] = pd.read_csv('type1_data1.csv')
# ----> 3 df = pd.to_datetime(df['subscribed'])
#       5 df
#
# File ~\PycharmProjects\Synthea_with\.venv\lib\site-packages\pandas\core\tools\datetimes.py:1075, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1075     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1076 elif isinstance(arg, Index):
#    1077     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...

# %%
import pandas as pd
df = pd.read_csv('type1_data1.csv')

# %%
df['subscribed'] = pd.to_datetime(df['subscribed'])

# %%
df
# Out:
#         id   age city    f1  f2      f3    f4         f5 subscribed   views
# 0     id01   2.0   서울   NaN   0    gold  ENFJ  91.297791 2024-07-16  6820.0
# 1     id02   9.0   서울  70.0   1     NaN  ENFJ  60.339826 2024-05-12  2534.0
# 2     id03  27.0   서울  61.0   1    gold  ISTJ  17.252986 2024-03-16  7312.0
# 3     id04  75.0   서울   NaN   2     NaN  INFP  52.667078 2024-07-21   493.0
# 4     id05  24.0   서울  85.0   2     NaN  ISFJ  29.269869 2024-03-07  1338.0
# ..     ...   ...  ...   ...  ..     ...   ...        ...        ...     ...
# 115  id114  22.0   대구  23.0   0    gold  INTP   0.000000 2025-02-17  9747.0
# 116  id115  23.0   부산  65.0   0     vip  ENTP   0.000000 2025-02-17  5628.0
# 117  id116  23.0   서울  12.0   1  silver  INFP   0.000000 2025-02-17  1267.0
# 118  id117  23.0   대구  65.0   2    gold  INFP   0.000000 2025-02-17  6543.0
# 119  id118  24.0   부산  94.0   1     vip  ESFJ   0.000000 2025-02-17  2356.0
#
# [120 rows x 10 columns]

# %%
df['year'] = df['subscribed'].dt.year
df['month'] = df['subscribed'].dt.month
df['day'] = df['subscribed'].dt.day

# %%
df
# Out:
#         id   age city    f1  f2      f3    f4         f5 subscribed   views  \
# 0     id01   2.0   서울   NaN   0    gold  ENFJ  91.297791 2024-07-16  6820.0
# 1     id02   9.0   서울  70.0   1     NaN  ENFJ  60.339826 2024-05-12  2534.0
# 2     id03  27.0   서울  61.0   1    gold  ISTJ  17.252986 2024-03-16  7312.0
# 3     id04  75.0   서울   NaN   2     NaN  INFP  52.667078 2024-07-21   493.0
# 4     id05  24.0   서울  85.0   2     NaN  ISFJ  29.269869 2024-03-07  1338.0
# ..     ...   ...  ...   ...  ..     ...   ...        ...        ...     ...
# 115  id114  22.0   대구  23.0   0    gold  INTP   0.000000 2025-02-17  9747.0
# 116  id115  23.0   부산  65.0   0     vip  ENTP   0.000000 2025-02-17  5628.0
# 117  id116  23.0   서울  12.0   1  silver  INFP   0.000000 2025-02-17  1267.0
# 118  id117  23.0   대구  65.0   2    gold  INFP   0.000000 2025-02-17  6543.0
# 119  id118  24.0   부산  94.0   1     vip  ESFJ   0.000000 2025-02-17  2356.0
#
#      year  month  day
# 0    2024      7   16
# ...

# %%
cond1 = df['year'] == 2024
cond2 = df['month'] == 2
cond3 = df['f3'] == 'gold'

df = df[cond1&cond2&cond3]


print(len(df))
# Out:
# 5

# %%
import pandas as pd

df = pd.read_csv('type1_data1.csv')
cond = df['views'] <= 1000
df = df[cond]

# %%
df = df['f4'].value_counts()

# %%
df
# Out:
# f4
# ISFJ    3
# INFP    2
# ESTJ    2
# INTP    2
# ISFP    1
# Name: count, dtype: int64

# %%
print(df.index[0])
# Out:
# ISFJ

# %%
import pandas as pd

df = pd.read_csv('type1_data1.csv')

# %%
cond = df['views'] <= 1000
df = df[cond]

# %%
df['f4'].mode()[0]
# Out:
# 'ISFJ'

# %%
import pandas as pd

df = pd.read_csv('type1_data1.csv')

# %%
df.dropna( inplace= True)
df = df.groupby(['city']).mean(numeric_only = True)

# %%
df
# Out:
#             age         f1        f2         f5        views
# city
# 경기    48.704000  61.360000  0.760000  52.106731  8127.880000
# 대구    49.773333  66.200000  0.666667  27.370166  6819.133333
# 부산    35.075000  65.875000  0.687500  38.638715  6945.437500
# 서울    38.000000  60.142857  0.785714  41.122705  7369.142857

# %%
print(df.sort_values('f2', ascending=False).index[0])
# Out:
# 서울
