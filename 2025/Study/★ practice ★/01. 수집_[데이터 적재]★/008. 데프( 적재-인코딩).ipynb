# %%
import pandas as pd

titanic = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.xls")

titanic.head(3)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8732\636516785.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 titanic = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.xls")
#       4
#       5 titanic.head(3)
#
# ...

# %%
import pandas as pd

titanic = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.xls", encoding='cp949')

titanic.head(3)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8732\708539853.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 titanic = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.xls", encoding='cp949')
#       4
#       5 titanic.head(3)
#
# ...

# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\wkdal\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\wkdal\anaconda3\lib\site-packages)

# %%
import chardet

with open("C://Users//wkdal//Desktop//archive//titanic.xls", 'rb') as f:
    raw = f.read()
    result = chardet.detect(raw)
    print(result)  # {'encoding': '...', 'confidence': 0.99}
# Out:
# {'encoding': 'Windows-1254', 'confidence': 0.42143171091256465, 'language': 'Turkish'}

# %%
import pandas as pd

titanic = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.csv", encoding='Windows-1254')

titanic.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2     1.0       0.0    Allison, Miss. Helen Loraine  female   2.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
