# %%
import pandas as pd

dataframe = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.csv")

dataframe.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2     1.0       0.0    Allison, Miss. Helen Loraine  female   2.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
# 해당 열에 누락된 값이 있나? (누락된 값을 선택하고, 두 개의 행 출력)  # isnull() Pandas에서 결측값(NaN), NaN이면 True

dataframe[dataframe['age'].isnull()].head()
# Out:
#     pclass  survived                                               name  \
# 15     1.0       0.0                                Baumann, Mr. John D
# 37     1.0       1.0      Bradley, Mr. George ("George Arthur Brayton")
# 40     1.0       0.0                          Brewe, Dr. Arthur Jackson
# 46     1.0       0.0                              Cairns, Mr. Alexander
# 59     1.0       1.0  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#        sex  age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 15    male  NaN    0.0    0.0  PC 17318  25.9250   NaN        S  NaN   NaN
# 37    male  NaN    0.0    0.0    111427  26.5500   NaN        S    9   NaN
# 40    male  NaN    0.0    0.0    112379  39.6000   NaN        C  NaN   NaN
# 46    male  NaN    0.0    0.0    113798  31.0000   NaN        S  NaN   NaN
# 59  female  NaN    0.0    0.0     17770  27.7208   NaN        C    5   NaN
#
#            home.dest
# 15      New York, NY
# 37   Los Angeles, CA
# ...

# %%
# 일부로 null값 만들어보기.

import numpy as np

dataframe['sex'] = dataframe['sex'].replace('male',np.nan) # head를 loc[]으로 변경할 수 있다.

# %%
dataframe[dataframe['sex'].isnull()].tail()  # head, tail 를 loc[]으로 변경할 수 있다.
# Out:
#       pclass  survived                       name  sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  NaN   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer  NaN  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin  NaN  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo  NaN  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN  NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN
