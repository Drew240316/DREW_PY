# %%
import pandas as pd

dataframe = pd.read_csv("C://Users//wkdal//Desktop//archive//titanic.csv")

dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# 데프 값 치환.

dataframe['sex'].replace('female','woman').head(3)
# Out:
# 0    woman
# 1     male
# 2    woman
# Name: sex, dtype: object

# %%
# 데프 두개의 값 하나로 동시 치환

dataframe['sex'].replace(['woman','male'],"person").head(3)
# Out:
# 0    female
# 1    person
# 2    female
# Name: sex, dtype: object

# %%
# 데프 두개의 값 각각의 값으로 동시 치환

dataframe.replace({"female":1,"male":0}).head(3)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_13368\366372753.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataframe.replace({"female":1,"male":0}).head(3)
#    pclass  survived                            name  sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  1.0  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor  0.0   0.9167    1.0
# 2     1.0       0.0    Allison, Miss. Helen Loraine  1.0   2.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# ...
